# %%
import numpy as np
import pandas as pd
import os
import urllib
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
url = "https://covid19.who.int/WHO-COVID-19-global-data.csv"
file_path = os.path.join("data","covid")

# %%
os.makedirs(file_path,exist_ok=True)
csv_path=os.path.join(file_path,"WHO-COVID-19-global-data.csv")
urllib.request.urlretrieve(url,csv_path)
# Out:
# ('data\\covid\\WHO-COVID-19-global-data.csv',
#  <http.client.HTTPMessage at 0x1ab3e5bcbe0>)

# %%
df = pd.read_csv(csv_path)

# %%
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 197416    2022-04-10           ZW     Zimbabwe       AFRO         33
# 197417    2022-04-11           ZW     Zimbabwe       AFRO         15
# 197418    2022-04-12           ZW     Zimbabwe       AFRO         37
# 197419    2022-04-13           ZW     Zimbabwe       AFRO         84
# 197420    2022-04-14           ZW     Zimbabwe       AFRO         66
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df_index = df.index
df_index
# Out:
# RangeIndex(start=0, stop=197421, step=1)

# %%
df_col = df.columns
df_col
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df_index.values
# Out:
# array([     0,      1,      2, ..., 197418, 197419, 197420], dtype=int64)

# %%
df.values
# Out:
# array([['2020-01-03', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-04', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-05', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ...,
#        ['2022-04-12', 'ZW', 'Zimbabwe', ..., 247010, 3, 5460],
#        ['2022-04-13', 'ZW', 'Zimbabwe', ..., 247094, 0, 5460],
#        ['2022-04-14', 'ZW', 'Zimbabwe', ..., 247160, 0, 5460]],
#       dtype=object)

# %%
df.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
df.shape
# Out:
# (197421, 8)

# %%
df.head(10)
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
# 5    2020-01-08           AF  Afghanistan       EMRO          0
# 6    2020-01-09           AF  Afghanistan       EMRO          0
# 7    2020-01-10           AF  Afghanistan       EMRO          0
# 8    2020-01-11           AF  Afghanistan       EMRO          0
# 9    2020-01-12           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# ...

# %%
df.tail(10)
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 197411    2022-04-05           ZW  Zimbabwe       AFRO         87
# 197412    2022-04-06           ZW  Zimbabwe       AFRO        132
# 197413    2022-04-07           ZW  Zimbabwe       AFRO         59
# 197414    2022-04-08           ZW  Zimbabwe       AFRO         67
# 197415    2022-04-09           ZW  Zimbabwe       AFRO         55
# 197416    2022-04-10           ZW  Zimbabwe       AFRO         33
# 197417    2022-04-11           ZW  Zimbabwe       AFRO         15
# 197418    2022-04-12           ZW  Zimbabwe       AFRO         37
# 197419    2022-04-13           ZW  Zimbabwe       AFRO         84
# 197420    2022-04-14           ZW  Zimbabwe       AFRO         66
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 197411            246612           5               5451
# 197412            246744           0               5451
# 197413            246803           2               5453
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197421 entries, 0 to 197420
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      197421 non-null  object
#  1   Country_code       196588 non-null  object
#  2   Country            197421 non-null  object
#  3   WHO_region         197421 non-null  object
#  4   New_cases          197421 non-null  int64
#  5   Cumulative_cases   197421 non-null  int64
#  6   New_deaths         197421 non-null  int64
#  7   Cumulative_deaths  197421 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 12.0+ MB

# %%
df.describe()
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  1.974210e+05      1.974210e+05  197421.000000      197421.000000
# mean   2.533603e+03      5.950420e+05      31.356082       11465.410286
# std    1.674116e+04      3.201608e+06     165.130815       53638.347807
# min   -3.295200e+04      0.000000e+00   -2460.000000           0.000000
# 25%    0.000000e+00      1.770000e+02       0.000000           2.000000
# 50%    2.500000e+01      1.088600e+04       0.000000         144.000000
# 75%    5.140000e+02      1.573110e+05       6.000000        2626.000000
# max    1.252624e+06      7.971696e+07   11447.000000      979321.000000

# %%
df["Country"]
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 197416       Zimbabwe
# 197417       Zimbabwe
# 197418       Zimbabwe
# 197419       Zimbabwe
# 197420       Zimbabwe
# Name: Country, Length: 197421, dtype: object

# %%
df["Country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
df.columns = [col.strip() for col in df.columns]
##to delete white space in columns " Country" => "Country"
df.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df.Country
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 197416       Zimbabwe
# 197417       Zimbabwe
# 197418       Zimbabwe
# 197419       Zimbabwe
# 197420       Zimbabwe
# Name: Country, Length: 197421, dtype: object

# %%
df.loc[1:4,'Country']
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: Country, dtype: object

# %%
df.loc[1:8,['Country','New_cases']]
# Out:
#        Country  New_cases
# 1  Afghanistan          0
# 2  Afghanistan          0
# 3  Afghanistan          0
# 4  Afghanistan          0
# 5  Afghanistan          0
# 6  Afghanistan          0
# 7  Afghanistan          0
# 8  Afghanistan          0

# %%
df.Country == 'Malaysia'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 197416    False
# 197417    False
# 197418    False
# 197419    False
# 197420    False
# Name: Country, Length: 197421, dtype: bool

# %%
df[df.Country == 'Malaysia']
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 104125    2020-01-03           MY  Malaysia       WPRO          0
# 104126    2020-01-04           MY  Malaysia       WPRO          0
# 104127    2020-01-05           MY  Malaysia       WPRO          0
# 104128    2020-01-06           MY  Malaysia       WPRO          0
# 104129    2020-01-07           MY  Malaysia       WPRO          0
# ...              ...          ...       ...        ...        ...
# 104953    2022-04-10           MY  Malaysia       WPRO      10177
# 104954    2022-04-11           MY  Malaysia       WPRO       8112
# 104955    2022-04-12           MY  Malaysia       WPRO       7739
# 104956    2022-04-13           MY  Malaysia       WPRO       9002
# 104957    2022-04-14           MY  Malaysia       WPRO      10052
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 104125                 0           0                  0
# 104126                 0           0                  0
# ...

# %%
df[df.New_cases > 10000]
# Out:
#        Date_reported Country_code    Country WHO_region  New_cases  \
# 6898      2020-08-24           AR  Argentina       AMRO      10278
# 6899      2020-08-25           AR  Argentina       AMRO      10406
# 6900      2020-08-26           AR  Argentina       AMRO      11440
# 6901      2020-08-27           AR  Argentina       AMRO      11358
# 6902      2020-08-28           AR  Argentina       AMRO      11181
# ...              ...          ...        ...        ...        ...
# 194084    2022-04-10           VN   Viet Nam       WPRO      34140
# 194085    2022-04-11           VN   Viet Nam       WPRO      28307
# 194086    2022-04-12           VN   Viet Nam       WPRO      51924
# 194087    2022-04-13           VN   Viet Nam       WPRO      22804
# 194088    2022-04-14           VN   Viet Nam       WPRO      24623
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 6898              393174         374              15605
# ...

# %%
df.loc[df.New_cases > 10000, ['New_deaths','Country']]
# Out:
#         New_deaths    Country
# 6898           374  Argentina
# 6899           340  Argentina
# 6900           374  Argentina
# 6901           365  Argentina
# 6902           349  Argentina
# ...            ...        ...
# 194084          26   Viet Nam
# 194085          19   Viet Nam
# 194086          17   Viet Nam
# 194087          28   Viet Nam
# 194088          20   Viet Nam
#
# [8992 rows x 2 columns]

# %%
df.loc[ (df.New_deaths>100) & (df.Country_code=='MY'),['Date_reported','Country','New_cases','New_deaths'] ]
# Out:
#        Date_reported   Country  New_cases  New_deaths
# 104642    2021-06-03  Malaysia       7703         126
# 104643    2021-06-04  Malaysia       8209         103
# 104645    2021-06-06  Malaysia       7452         109
# 104655    2021-06-16  Malaysia       5419         101
# 104669    2021-06-30  Malaysia       6437         107
# ...              ...       ...        ...         ...
# 104769    2021-10-08  Malaysia       9890         132
# 104774    2021-10-13  Malaysia       7276         103
# 104915    2022-03-03  Malaysia      27500         115
# 104922    2022-03-10  Malaysia      30246         113
# 104929    2022-03-17  Malaysia      28298         105
#
# [97 rows x 4 columns]

# %%
df.loc[df.Country_code=='MY',['New_cases']].max()
# Out:
# New_cases    33406
# dtype: int64

# %%
df.loc[df.Country_code=='MY',['New_cases']].min()
# Out:
# New_cases    0
# dtype: int64

# %%
df.loc[df.Country_code=='MY',['New_cases']].sum()
# Out:
# New_cases    4352611
# dtype: int64

# %%
df.loc[df.Country_code=='MY',['New_deaths']].sum()
# Out:
# New_deaths    35363
# dtype: int64

# %%
df.loc[df.Country_code=='MY',['Cumulative_deaths']].max()
# Out:
# Cumulative_deaths    35363
# dtype: int64

# %%
df.New_deaths.idxmax()
# Out:
# 34962

# %%
df.loc[df.New_deaths.idxmax(),['Date_reported','Country','New_cases','New_deaths']]
# Out:
# Date_reported    2022-03-22
# Country               Chile
# New_cases              8167
# New_deaths            11447
# Name: 34962, dtype: object

# %%
df[df.New_deaths < 0]
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 11902     2020-08-30           BS                   Bahamas       AMRO
# 13974     2021-10-10           BD                Bangladesh      SEARO
# 17081     2021-02-27           BZ                    Belize       AMRO
# 23285     2022-03-07           BW                  Botswana       AFRO
# 60578     2021-08-27           FR                    France       EURO
# 60587     2021-09-05           FR                    France       EURO
# 61268     2021-04-06           GF             French Guiana       AMRO
# 70088     2020-04-28           GP                Guadeloupe       AMRO
# 70269     2020-10-26           GP                Guadeloupe       AMRO
# 71749     2020-04-23           GT                 Guatemala       AMRO
# 71760     2020-05-04           GT                 Guatemala       AMRO
# 77844     2021-01-12           HN                  Honduras       AMRO
# ...

# %%
df['pct_cases'] = ( df['New_cases'] / df['Cumulative_cases'] ) * 100
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 197416    2022-04-10           ZW     Zimbabwe       AFRO         33
# 197417    2022-04-11           ZW     Zimbabwe       AFRO         15
# 197418    2022-04-12           ZW     Zimbabwe       AFRO         37
# 197419    2022-04-13           ZW     Zimbabwe       AFRO         84
# 197420    2022-04-14           ZW     Zimbabwe       AFRO         66
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  pct_cases
# 0                      0           0                  0        NaN
# ...

# %%
df['New_cases'].plot(kind='density', figsize=(14,6)) # kde
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['New_cases'].plot(kind='box',vert=False, figsize=(14,6)) # kde
# Out:
# <AxesSubplot:>

# %%
ax = df['New_Cases'].plot(kind='density', figsize=(14,6)) # kde
ax.axvline(df['New_Cases'].mean(), color='red')
ax.axvline(df['New_cases'].median(), color='green')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'New_Cases'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
